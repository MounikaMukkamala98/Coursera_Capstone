# %% [markdown]
# <h1> Battle of Neighborhood </h1>

# %% [markdown]
# <p>I did not choose any other project. I have selected the project from week1.</p>

# %% [markdown]
# <p> Based on the given data Segmentation and clustering is done which can be useful for particluar user</p>
